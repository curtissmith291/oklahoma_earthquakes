# %% [markdown]
# This workbook is used to download earthquake data from the USGS database.
# The database does not let you specify the state, so a 500km radius circle
# was centered over Oklahoma; results will be filtered to exclude surrounding
# states.

# %%
import requests
import pandas as pd
import json

# %%
_2014 = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2009-01-01&endtime=2014-12-31&latitude=35.61&longitude=-97.48&maxradiuskm=500').json()

# %%
test
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1627607947000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2009-01-01&endtime=2014-12-31&latitude=35.61&longitude=-97.48&maxradiuskm=500',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.12.1',
#   'count': 5727},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '6 km N of Fallis, Oklahoma',
#     'time': 1419982766600,
#     'updated': 1426559898040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usc000tf1p',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usc000tf1p&format=geojson',
#     'felt': 0,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'us',
#     'code': 'c000tf1p',
#     'ids': ',usc000tf1p,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
# ...

# %%
with open('../oklahoma_earthquakes_largefiles/eq_2009-2014.json', 'w') as outfile:
    json.dump(test, outfile, indent = 4)

# %%
_2018 = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2015-01-01&endtime=2018-12-31&latitude=35.61&longitude=-97.48&maxradiuskm=500').json()

# %%
with open('../oklahoma_earthquakes_largefiles/eq_2015-2018.json', 'w') as outfile:
    json.dump(_2018, outfile, indent = 4)

# %%
_2021 = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2019-01-01&endtime=2021-06-30&latitude=35.61&longitude=-97.48&maxradiuskm=500').json()

# %%
with open('../oklahoma_earthquakes_largefiles/eq_2019-2021.json', 'w') as outfile:
    json.dump(_2021, outfile, indent = 4)

# %%
_2006 = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2006-01-01&endtime=2008-12-31&latitude=35.61&longitude=-97.48&maxradiuskm=500').json()

# %%
with open('../oklahoma_earthquakes_largefiles/usgs_pre-cleaned/eq_2006-2008.json', 'w') as outfile:
    json.dump(_2006, outfile, indent = 4)
