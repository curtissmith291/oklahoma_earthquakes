# %%
import plotly
import pandas as pd
import plotly.express as px

# %%
eq_df = pd.read_csv('../oklahoma_earthquakes_largefiles/usgs_cleaned/usgs_eqs_reduced_data.csv',  low_memory=False)

# %%
eq_df
# Out:
#                id           time  mag magType  cdi  \
# 0      us2000iz6u  1546166814510  2.2   mb_lg  NaN
# 1      us2000iz51  1546159833730  2.0   mb_lg  NaN
# 2      us2000iz4w  1546158498840  2.2      ml  NaN
# 3      us2000iyvs  1546073324730  2.5   mb_lg  3.3
# 4      us2000iyvq  1546073222930  2.2   mb_lg  NaN
# ...           ...            ...  ...     ...  ...
# 20619  usp000gucq  1235535255330  3.3    mblg  3.8
# 20620  usp000gu9h  1235295786750  3.2    mblg  3.8
# 20621  usp000gtdu  1233656590010  3.1    mblg  2.2
# 20622  usp000gt8m  1233277072380  2.4    mblg  2.9
# 20623  usp000gt6w  1233141549470  3.4    mblg  4.1
#
#                                     place    status  latitude  longitude  \
# 0      6 km ESE of Cleo Springs, Oklahoma  reviewed   36.3818   -98.3804
# 1      5 km ESE of Cleo Springs, Oklahoma  reviewed   36.3917   -98.3808
# 2           13 km NNW of Pawnee, Oklahoma  reviewed   36.4443   -96.8762
# ...

# %%
eq_df["year"] = eq_df.date.apply(lambda x: x[0:4])
eq_df
# Out:
#                id           time  mag magType  cdi  \
# 0      us2000iz6u  1546166814510  2.2   mb_lg  NaN
# 1      us2000iz51  1546159833730  2.0   mb_lg  NaN
# 2      us2000iz4w  1546158498840  2.2      ml  NaN
# 3      us2000iyvs  1546073324730  2.5   mb_lg  3.3
# 4      us2000iyvq  1546073222930  2.2   mb_lg  NaN
# ...           ...            ...  ...     ...  ...
# 20619  usp000gucq  1235535255330  3.3    mblg  3.8
# 20620  usp000gu9h  1235295786750  3.2    mblg  3.8
# 20621  usp000gtdu  1233656590010  3.1    mblg  2.2
# 20622  usp000gt8m  1233277072380  2.4    mblg  2.9
# 20623  usp000gt6w  1233141549470  3.4    mblg  4.1
#
#                                     place    status  latitude  longitude  \
# 0      6 km ESE of Cleo Springs, Oklahoma  reviewed   36.3818   -98.3804
# 1      5 km ESE of Cleo Springs, Oklahoma  reviewed   36.3917   -98.3808
# 2           13 km NNW of Pawnee, Oklahoma  reviewed   36.4443   -96.8762
# ...

# %%
eq_df["mag_size"] = eq_df.mag.apply(lambda x: x**5)
eq_df
# Out:
#                id           time  mag magType  cdi  \
# 0      us2000iz6u  1546166814510  2.2   mb_lg  NaN
# 1      us2000iz51  1546159833730  2.0   mb_lg  NaN
# 2      us2000iz4w  1546158498840  2.2      ml  NaN
# 3      us2000iyvs  1546073324730  2.5   mb_lg  3.3
# 4      us2000iyvq  1546073222930  2.2   mb_lg  NaN
# ...           ...            ...  ...     ...  ...
# 20619  usp000gucq  1235535255330  3.3    mblg  3.8
# 20620  usp000gu9h  1235295786750  3.2    mblg  3.8
# 20621  usp000gtdu  1233656590010  3.1    mblg  2.2
# 20622  usp000gt8m  1233277072380  2.4    mblg  2.9
# 20623  usp000gt6w  1233141549470  3.4    mblg  4.1
#
#                                     place    status  latitude  longitude  \
# 0      6 km ESE of Cleo Springs, Oklahoma  reviewed   36.3818   -98.3804
# 1      5 km ESE of Cleo Springs, Oklahoma  reviewed   36.3917   -98.3808
# 2           13 km NNW of Pawnee, Oklahoma  reviewed   36.4443   -96.8762
# ...

# %%
eq_2011 = eq_df[(eq_df["year"] == "2011") & (eq_df["mag"] >= 3)]

# %%
eq_2012 = eq_df[(eq_df["year"] == "2012") & (eq_df["mag"] >= 3)]

# %%
eq_2013 = eq_df[(eq_df["year"] == "2013") & (eq_df["mag"] >= 3)]

# %%
eq_2014 = eq_df[(eq_df["year"] == "2014") & (eq_df["mag"] >= 3)]

# %%
eq_2015 = eq_df[(eq_df["year"] == "2015") & (eq_df["mag"] >= 3)]

# %%
eq_2016 = eq_df[(eq_df["year"] == "2016") & (eq_df["mag"] >= 3)]

# %%
eq_2017 = eq_df[(eq_df["year"] == "2017") & (eq_df["mag"] >= 3)]

# %%
eq_2018 = eq_df[(eq_df["year"] == "2018") & (eq_df["mag"] >= 3)]

# %%
eq_2019 = eq_df[(eq_df["year"] == "2019") & (eq_df["mag"] >= 3)]
eq_2019
# Out:
#                id           time   mag magType  cdi  \
# 15389  ok2019znrk  1577685475689  3.73      ml  4.6
# 15410  ok2019zeyr  1577273073350  3.38      ml  5.1
# 15493  ok2019ynba  1576426145679  3.59      ml  4.1
# 15576  ok2019xrnu  1575408975380  3.07      ml  5.2
# 15586  ok2019xozr  1575288731259  3.75      ml  4.9
# 15620  ok2019xgdd  1574869386669  3.05      ml  3.4
# 15665  ok2019xaic  1574594695530  3.48      ml  3.1
# 15676  ok2019wxlw  1574459689700  3.57      ml  3.8
# 15677  ok2019wxlv  1574459645660  3.58      ml  3.4
# 15683  ok2019wwfw  1574401476170  3.60     mwr  5.7
# 15803  ok2019vrov  1572951836210  3.06      ml  3.8
# 15933  ok2019ustp  1571778238750  3.67      ml  3.8
# 15950  ok2019uqoj  1571674155339  3.13      ml  3.1
# 16050  ok2019ttca  1570564055759  3.01      ml  2.0
# 16052  ok2019ttav  1570561845210  3.03      ml  2.2
# 16155  ok2019syps  1569595859979  3.45      ml  2.0
# 16212  ok2019soid  1569109090449  3.09      ml  NaN
# ...

# %%
eq_2020 = eq_df[(eq_df["year"] == "2020") & (eq_df["mag"] >= 3)]
eq_2020.head()
# Out:
#                id           time   mag magType  cdi  \
# 10868  ok2020zdwy  1608758894519  3.11      ml  2.8
# 11031  ok2020yeov  1607561605719  3.02      ml  NaN
# 11683  ok2020uvdc  1603426092289  3.32      ml  3.3
# 11690  ok2020uuxm  1603415853130  3.22      ml  2.2
# 11724  ok2020utio  1603341428650  3.10      ml  3.4
#
#                                 place    status   latitude  longitude  depth  \
# 10868  10 km NNE of Quinlan, Oklahoma  reviewed  36.534333 -98.983667   6.97
# 11031   9 km NNE of Quinlan, Oklahoma  reviewed  36.529833 -98.988167   7.88
# 11683      7 km N of Nardin, Oklahoma  reviewed  36.874000 -97.446833   7.56
# 11690      7 km N of Nardin, Oklahoma  reviewed  36.874333 -97.448500   7.76
# 11724     9 km NNW of Perry, Oklahoma  reviewed  36.364500 -97.344500   6.95
#
#                           date  year    mag_size
# 10868  2020-12-23 21:28:14.519  2020  290.939002
# 11031  2020-12-10 00:53:25.719  2020  251.208722
# ...

# %%
import plotly.graph_objects as go

# %%
inj_2011 = pd.read_csv('../oklahoma_earthquakes_largefiles/sql_export/inj_2011.csv',  low_memory=False)
inj_2011.head()
# Out:
#           api        lat        lon  year_volume
# 0  3500300026  36.900446 -98.219252       1656.0
# 1  3500300163  36.896458 -98.179582      10800.0
# 2  3500321074  36.888738 -98.319802          0.0
# 3  3500321107  36.892139 -98.196351      13020.0
# 4  3500321242  36.592341 -98.463515       4350.0

# %%
inj_2011 = inj_2011[inj_2011.year_volume > 0]
inj_2011.head()
# Out:
#           api        lat        lon  year_volume
# 0  3500300026  36.900446 -98.219252       1656.0
# 1  3500300163  36.896458 -98.179582      10800.0
# 3  3500321107  36.892139 -98.196351      13020.0
# 4  3500321242  36.592341 -98.463515       4350.0
# 5  3500321328  36.674104 -98.515650      13087.0

# %%
inj_2011.sort_values(by="year_volume", ascending = False, inplace = True)

# %%
inj_2011 = inj_2011.head(100)

# %%
fig=go.Figure()

fig.add_trace(go.Scattermapbox(
    lat=inj_2011.lat, 
    lon=inj_2011.lon,
    name = "inj-2011",
    text = inj_2011['year_volume'],
    visible = True,
    mode = 'markers',
    legendrank = 1,
    legendgroup="group",
    opacity = 1,
#     hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = 10,
        opacity = 1,
#         colorscale = 'black',
        color = 'Black',
        colorbar_title="Inj. Location"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2011.latitude, 
    lon=eq_2011.longitude,
    name = "2011",
    text = eq_2011['place'],
    visible = True,
    mode = 'markers',
    legendgroup="group2",
    opacity = 0.8,
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2011.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2011.mag,
        cmin = 3,
        cmax = eq_2011.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2012.latitude, 
    lon=eq_2012.longitude,
    name = "2012",
    text = eq_2012['place'],
    visible = False,
    mode = 'markers',
    opacity = 0.8,
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2012.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2012.mag,
        cmin = 3,
        cmax = eq_2012.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2013.latitude, 
    lon=eq_2013.longitude,
    name = "2013",
    text = eq_2013['place'],
    visible = False,
    mode = 'markers',
    opacity = 0.8,
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2013.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2013.mag,
        cmin = 3,
        cmax = eq_2013.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2014.latitude, 
    lon=eq_2014.longitude,
    name = "2014",
    text = eq_2014['place'],
    visible = False,
    mode = 'markers',
    opacity = 0.8,
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2014.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2014.mag,
        cmin = 3,
        cmax = eq_2014.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2015.latitude, 
    lon=eq_2015.longitude,
    name = "2015",
    text = eq_2015['place'],
    visible = False,
    mode = 'markers',
    opacity = 0.8,
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2015.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2015.mag,
        cmin = 3,
        cmax = eq_2015.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2016.latitude, 
    lon=eq_2016.longitude,
    name = "2016",
    text = eq_2016['place'],
    visible = False,
    mode = 'markers',
    opacity = 0.8,
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2016.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2016.mag,
        cmin = 3,
        cmax = eq_2016.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2017.latitude, 
    lon=eq_2017.longitude,
    name = "2017",
    text = eq_2017['place'],
    visible = False,
    mode = 'markers',
    opacity = 0.8,
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2017.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2017.mag,
        cmin = 3,
        cmax = eq_2017.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2018.latitude, 
    lon=eq_2018.longitude,
    name = "2018",
    text = eq_2018['place'],
    visible = False,
    mode = 'markers',
    opacity = 0.8,
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2018.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2018.mag,
        cmin = 3,
        cmax = eq_2018.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2019.latitude, 
    lon=eq_2019.longitude,
    name = "2019",
    text = eq_2019['place'],
    visible = False,
    mode = 'markers',
    opacity = 0.8,
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2019.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2019.mag,
        cmin = 3,
        cmax = eq_2019.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.add_trace(go.Scattermapbox(
    lat=eq_2020.latitude, 
    lon=eq_2020.longitude,
    name = "2020",
    text = eq_2020['place'],
    visible = False,
    mode = 'markers',
    hovertemplate = "Magnitude: %{marker.color} </b><br>" + "Location: %{text}<br>",
    marker = dict(
        size = eq_2020.mag**2.2,
        opacity = 0.8,
        colorscale = 'jet',
        color = eq_2020.mag,
        cmin = 3,
        cmax = eq_2020.mag.max(),
        colorbar_title="Magnitude"
    )))

fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=[{"visible": [True, True, False, False, False, False, False, False, False, False, False]}],
                    label="2011",
                    method="update"
                ),
                dict(
                    args=[{"visible": [True, False, True, False, False, False, False, False, False, False, False]}],
                    label="2012",
                    method="update"
                ),
                dict(
                    args=[{"visible": [True, False, False, True, False, False, False, False, False, False, False]}],
                    label="2013",
                    method="update"
                ),
                dict(
                    args=[{"visible": [True, False, False, False, True, False, False, False, False, False, False, False]}],
                    label="2014",
                    method="update"
                ),
                dict(
                    args=[{"visible": [True, False, False, False, False, True, False, False, False, False, False]}],
                    label="2015",
                    method="update"
                ),
                dict(
                    args=[{"visible": [True, False, False, False, False, False, True, False, False, False, False]}],
                    label="2016",
                    method="update"
                ),
                dict(
                    args=[{"visible": [True, False, False, False, False, False, False, True, False, False, False]}],
                    label="2017",
                    method="update"
                ),
                dict(
                    args=[{"visible": [True, False, False, False, False, False, False, False, True, False, False]}],
                    label="2018",
                    method="update"
                ),
                dict(
                    args=[{"visible": [True, False, False, False, False, False, False, False, False, True, False]}],
                    label="2019",
                    method="update"
                ),
                dict(
                    args=[{"visible": [True, False, False, False, False, False, False, False, False, False, True]}],
                    label="2020",
                    method="update"
                ),
            ]),
            direction="down",

        )])

fig.update_layout(
    title = 'M>3 Earthquakes in Oklahoma',
    mapbox = {
        'style': "carto-positron", 
        'zoom': 5.5,
        'center':dict(lat=35.5, lon=-97.4)
    })

fig.show()
# Out:
# <div>                            <div id="ffeaf9a5-1202-46ff-ba63-d5922c164da4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffeaf9a5-1202-46ff-ba63-d5922c164da4")) {                    Plotly.newPlot(                        "ffeaf9a5-1202-46ff-ba63-d5922c164da4",                        [{"lat":[34.29914,34.300940000000004,35.433165,35.433165,34.30457,35.433165,35.433165,36.072005,35.403847,35.403847,35.37645,36.89353,36.90277778,35.37645,35.433165,36.90591,36.90842,35.404144,36.90658333,36.91245,35.403847,35.404144,35.404144,35.37645,36.126785999999996,36.126785999999996,36.378628000000006,36.378628000000006,35.404144,36.126785999999996,35.403847,36.126785999999996,36.126785999999996,36.079271000000006,36.079271000000006,36.126785999999996,36.12
# ...
