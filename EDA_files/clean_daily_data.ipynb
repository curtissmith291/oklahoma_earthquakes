# %%
import pandas as pd

# %%
df = pd.read_csv("../oklahoma_earthquakes_largefiles/injection_pre-cleaned/arb_2014.csv", low_memory=False)
df.head()
# Out:
#             API       Well_Name Well_Number  Operator_Number  \
# 0  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
# 1  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
# 2  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
# 3  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
# 4  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
#
#                             Operator_Name Daily_Report_Date_Start  \
# 0  SANDRIDGE EXPLORATION & PRODUCTION LLC                11/23/14
# 1  SANDRIDGE EXPLORATION & PRODUCTION LLC                11/23/14
# 2  SANDRIDGE EXPLORATION & PRODUCTION LLC                11/23/14
# 3  SANDRIDGE EXPLORATION & PRODUCTION LLC                11/23/14
# 4  SANDRIDGE EXPLORATION & PRODUCTION LLC                11/23/14
#
#   Daily_Report_Date_End Report_Date  Volume_BPD  Pressure_PSI   Latitude  \
# 0               3/29/20    12/31/14      3246.0           0.0  36.928442
# ...

# %%
df.dtypes
# Out:
# API                        float64
# Well_Name                   object
# Well_Number                 object
# Operator_Number            float64
# Operator_Name               object
# Daily_Report_Date_Start     object
# Daily_Report_Date_End       object
# Report_Date                 object
# Volume_BPD                 float64
# Pressure_PSI               float64
# Latitude                   float64
# Longitude                  float64
# DirArea                     object
# Directive_Status            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249509 entries, 0 to 249508
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   API                      15411 non-null  float64
#  1   Well_Name                15411 non-null  object
#  2   Well_Number              15411 non-null  object
#  3   Operator_Number          15411 non-null  float64
#  4   Operator_Name            15411 non-null  object
#  5   Daily_Report_Date_Start  15411 non-null  object
#  6   Daily_Report_Date_End    15411 non-null  object
#  7   Report_Date              15411 non-null  object
#  8   Volume_BPD               15411 non-null  float64
#  9   Pressure_PSI             15411 non-null  float64
#  10  Latitude                 15411 non-null  float64
#  11  Longitude                15411 non-null  float64
#  12  DirArea                  14952 non-null  object
# ...

# %%
df.dropna(how='all', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   API                      15411 non-null  float64
#  1   Well_Name                15411 non-null  object
#  2   Well_Number              15411 non-null  object
#  3   Operator_Number          15411 non-null  float64
#  4   Operator_Name            15411 non-null  object
#  5   Daily_Report_Date_Start  15411 non-null  object
#  6   Daily_Report_Date_End    15411 non-null  object
#  7   Report_Date              15411 non-null  object
#  8   Volume_BPD               15411 non-null  float64
#  9   Pressure_PSI             15411 non-null  float64
#  10  Latitude                 15411 non-null  float64
#  11  Longitude                15411 non-null  float64
#  12  DirArea                  14952 non-null  object
#  13  Directive_Status         15258 non-null  object
# ...

# %%
df.iloc[:, 5:8] = df.iloc[:, 5:8].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   API                      15411 non-null  float64
#  1   Well_Name                15411 non-null  object
#  2   Well_Number              15411 non-null  object
#  3   Operator_Number          15411 non-null  float64
#  4   Operator_Name            15411 non-null  object
#  5   Daily_Report_Date_Start  15411 non-null  datetime64[ns]
#  6   Daily_Report_Date_End    15411 non-null  datetime64[ns]
#  7   Report_Date              15411 non-null  datetime64[ns]
#  8   Volume_BPD               15411 non-null  float64
#  9   Pressure_PSI             15411 non-null  float64
#  10  Latitude                 15411 non-null  float64
#  11  Longitude                15411 non-null  float64
#  12  DirArea                  14952 non-null  object
# ...

# %%
df.head()
# Out:
#             API       Well_Name Well_Number  Operator_Number  \
# 0  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
# 1  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
# 2  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
# 3  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
# 4  3.500322e+09  ROSE KELLY SWD         1-3          20357.0
#
#                             Operator_Name Daily_Report_Date_Start  \
# 0  SANDRIDGE EXPLORATION & PRODUCTION LLC              2014-11-23
# 1  SANDRIDGE EXPLORATION & PRODUCTION LLC              2014-11-23
# 2  SANDRIDGE EXPLORATION & PRODUCTION LLC              2014-11-23
# 3  SANDRIDGE EXPLORATION & PRODUCTION LLC              2014-11-23
# 4  SANDRIDGE EXPLORATION & PRODUCTION LLC              2014-11-23
#
#   Daily_Report_Date_End Report_Date  Volume_BPD  Pressure_PSI   Latitude  \
# 0            2020-03-29  2014-12-31      3246.0           0.0  36.928442
# ...

# %%
df["Volume_BPD"].describe()
# Out:
# count    15411.000000
# mean      4594.920550
# std       9605.496977
# min       -999.000000
# 25%        148.000000
# 50%       1276.000000
# 75%       4617.500000
# max      67849.000000
# Name: Volume_BPD, dtype: float64

# %%
df.describe()
# Out:
#                 API  Operator_Number    Volume_BPD  Pressure_PSI  \
# count  1.541100e+04     15411.000000  15411.000000  15411.000000
# mean   3.506885e+09     75983.049380   4594.920550     67.371477
# std    3.598970e+06     45530.355425   9605.496977    150.003031
# min    3.500322e+09      8896.000000   -999.000000   -999.000000
# 25%    3.505323e+09     20357.000000    148.000000      0.000000
# 50%    3.505323e+09     99931.000000   1276.000000      0.000000
# 75%    3.508324e+09    103155.000000   4617.500000     72.000000
# max    3.515124e+09    140825.000000  67849.000000   1100.000000
#
#            Latitude     Longitude
# count  15411.000000  15411.000000
# mean      36.345107    -97.710798
# std        0.489829      0.501647
# min       35.403716    -98.789998
# 25%       35.898084    -98.056283
# 50%       36.290910    -97.733090
# 75%       36.798470    -97.216827
# max       36.957722    -96.658860

# %%
df.drop(df[df['Volume_BPD'] < 0].index, inplace=True)

# %%
df.describe()
# Out:
#                 API  Operator_Number    Volume_BPD  Pressure_PSI  \
# count  1.540000e+04     15400.000000  15400.000000  15400.000000
# mean   3.506882e+09     75965.943701   4598.916207     68.133171
# std    3.597734e+06     45542.113695   9607.763091    147.323117
# min    3.500322e+09      8896.000000      0.000000    -39.000000
# 25%    3.505323e+09     20357.000000    149.000000      0.000000
# 50%    3.505323e+09     99931.000000   1284.981018      0.000000
# 75%    3.508324e+09    103155.000000   4621.000000     73.000000
# max    3.515124e+09    140825.000000  67849.000000   1100.000000
#
#            Latitude     Longitude
# count  15400.000000  15400.000000
# mean      36.345345    -97.711068
# std        0.489923      0.501724
# min       35.403716    -98.789998
# 25%       35.898084    -98.056283
# 50%       36.290910    -97.733090
# 75%       36.798470    -97.216827
# max       36.957722    -96.658860

# %%
df.to_csv("../oklahoma_earthquakes_largefiles/arb_2021_cleaned.csv", index = False)
